# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import schedule
import time
import logging
import random

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

def scrape_and_update_excel():
    url = 'https://rds2.northsouth.edu/index.php/common/showofferedcourses'
    courses = get_course_data(url)
    if courses:
        save_courses_to_excel(courses, 'course_data.xlsx')
    else:
        logging.warning('No courses found to save.')

def get_course_data(url, max_pages=2, max_retries=3, timeout=10):
    courses = []
    page = 1
    session = requests.Session()

    try:
        while page <= max_pages:
            retry_count = 0
            while retry_count < max_retries:
                try:
                    logging.info(f'Fetching page {page}')
                    start_time = time.time()

                    response = session.get(url, params={'page': page}, timeout=timeout)
                    response.raise_for_status()

                    soup = BeautifulSoup(response.content, 'html.parser')

                    table = soup.find('table', id='offeredCourseTbl')
                    if not table:
                        logging.warning(f'No table found on page {page}')
                        break

                    rows = table.find('tbody').find_all('tr')

                    if not rows:
                        logging.warning(f'No rows found on page {page}')
                        break

                    for row in rows:
                        cols = row.find_all('td')
                        if len(cols) == 7:  # Ensure there are exactly 7 columns
                            index = cols[0].text.strip()
                            course_name = cols[1].text.strip()
                            section = cols[2].text.strip()
                            faculty = cols[3].text.strip()
                            course_time = cols[4].text.strip()
                            room_number = cols[5].text.strip()
                            seats_available = cols[6].text.strip()
                            courses.append((index, course_name, section, faculty, course_time, room_number, seats_available))
                        else:
                            logging.warning(f'Row with unexpected number of columns: {len(cols)}')

                    page += 1
                    logging.info(f'Page {page} fetched in {time.time() - start_time:.2f} seconds')
                    break  # Break out of the retry loop if successful
                except requests.Timeout:
                    retry_count += 1
                    logging.warning(f'Timeout occurred. Retrying... ({retry_count}/{max_retries})')
                    time.sleep(2 ** retry_count)  # Exponential backoff
                except requests.RequestException as e:
                    logging.error(f'Error fetching data: {e}')
                    break

            if retry_count == max_retries:
                logging.error(f'Max retries reached for page {page}. Skipping to next page.')

            # Adding a random delay to avoid hitting the server too quickly
            time.sleep(random.uniform(1, 3))

    except Exception as e:
        logging.error(f'Unexpected error occurred: {e}')

    return courses

def save_courses_to_excel(courses, filename):
    try:
        df = pd.DataFrame(courses, columns=['Index', 'Course Name', 'Section', 'Faculty', 'Time', 'Room Number', 'Seats Available'])
        df.to_excel(filename, index=False)
        logging.info(f'Successfully saved courses to {filename}')
    except Exception as e:
        logging.error(f'Error saving courses to Excel: {e}')

# Schedule the update every 10 minutes
schedule.every(10).minutes.do(scrape_and_update_excel)

if __name__ == "__main__":
    scrape_and_update_excel()  # Initial run to create the file

    while True:
        schedule.run_pending()
        time.sleep(1)
# Out:
# 2024-07-03 13:56:29,597 - INFO - Fetching page 1
# 2024-07-03 13:56:29,600 - DEBUG - Starting new HTTPS connection (1): rds2.northsouth.edu:443
# 2024-07-03 13:56:32,599 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page=1 HTTP/11" 200 64286
# 2024-07-03 13:56:34,095 - INFO - Page 2 fetched in 4.50 seconds
# 2024-07-03 13:56:35,339 - INFO - Fetching page 2
# 2024-07-03 13:56:35,822 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page=2 HTTP/11" 200 64286
# 2024-07-03 13:56:37,203 - INFO - Page 3 fetched in 1.86 seconds
# 2024-07-03 13:56:41,345 - INFO - Successfully saved courses to course_data.xlsx
# 2024-07-03 14:06:29,659 - DEBUG - Running job Job(interval=10, unit=minutes, do=scrape_and_update_excel, args=(), kwargs={})
# 2024-07-03 14:06:29,662 - INFO - Fetching page 1
# 2024-07-03 14:06:29,666 - DEBUG - Starting new HTTPS connection (1): rds2.northsouth.edu:443
# 2024-07-03 14:06:30,171 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page
# 2024-07-03 14:18:54,952 - ERROR - Max retries reached for page 1. Skipping to next page.
# 2024-07-03 14:18:57,356 - INFO - Fetching page 1
# 2024-07-03 14:18:57,361 - DEBUG - Starting new HTTPS connection (10): rds2.northsouth.edu:443
# 2024-07-03 14:19:07,377 - WARNING - Timeout occurred. Retrying... (1/3)
# 2024-07-03 14:19:09,380 - INFO - Fetching page 1
# 2024-07-03 14:19:09,383 - DEBUG - Starting new HTTPS connection (11): rds2.northsouth.edu:443
# 2024-07-03 14:19:19,387 - WARNING - Timeout occurred. Retrying... (2/3)
# 2024-07-03 14:19:23,390 - INFO - Fetching page 1
# 2024-07-03 14:19:23,395 - DEBUG - Starting new HTTPS connection (12): rds2.northsouth.edu:443
# 2024-07-03 14:19:33,398 - WARNING - Timeout occurred. Retrying... (3/3)
# 2024-07-03 14:19:41,400 - ERROR - Max retries reached for page 1. Skipping to next page.
# 2024-07-03 14:19:44,352 - INFO - Fetching page 1
# 2024-07-03 14:19:44,356 - DEBUG - Starting new HTTPS connection (13): rds2.northsouth.edu:443
# 2024-07-03 14:19:54,365 - WARNING - Timeout occurred. Retrying... (1/3)
# 2024-07-03 14:19:56,368 - INFO - Fetching page 1
# 2024-07-03 14:19:56,370 - DEBUG - Starting new HTTPS connection (14): rds2.northsouth.edu:443
# 2024-07-03 14:20:06,375 - WARNING - Timeout occurred. Retrying... (2/3)
# 2024-07-03 14:20:10,377 - INFO - Fetching page 1
# 2024-07-03 14:20:10,380 - DEBUG - Starting new HTTPS connection (15): rds2.northsouth.edu:443
# 2024-07-03 14:20:20,386 - WARNING - Timeout occurred. Retrying... (3/3)
# 2024-07-03 14:20:28,388 - ERROR - Max retries reached for page 1. Skipping to next page.
# 2024-07-03 14:20:29,707 - INFO - Fetching page 1
# 2024-07-03 14:20:29,711 - DEBUG - Starting new HTTPS connection (16): rds2.northsouth.edu:443
# 2024-07-03 14:20:40,074 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page=1 HTTP/11" 200 64316
# 2024-07-03 14:20:41,431 - INFO - Page 2 fetched in 11.72 seconds
# 2024-07-03 14:20:43,855 - INFO - Fetching page 2
# 2024-07-03 14:20:44,337 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page=2 HTTP/11" 200 64316
# 2024-07-03 14:20:45,728 - INFO - Page 3 fetched in 1.87 seconds
# 2024-07-03 14:20:49,455 - INFO - Successfully saved courses to course_data.xlsx
# 2024-07-03 14:30:49,749 - DEBUG - Running job Job(interval=10, unit=minutes, do=scrape_and_update_excel, args=(), kwargs={})
# 2024-07-03 14:30:49,750 - INFO - Fetching page 1
# 2024-07-03 14:30:49,753 - DEBUG - Starting new HTTPS connection (1): rds2.northsouth.edu:443
# 2024-07-03 14:30:50,343 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page=1 HTTP/11" 200 64373
# 2024-07-03 14:30:51,692 - INFO - Page 2 fetched in 1.94 seconds
# 2024-07-03 14:30:53,499 - INFO - Fetching page 2
# 2024-07-03 14:30:53,987 - DEBUG - https://rds2.northsouth.edu:443 "GET /index.php/common/showofferedcourses?page=2 HTTP/11" 200 64373
# 2024-07-03 14:30:55,168 - INFO - Page 3 fetched in 1.67 seconds
# 2024-07-03 14:30:58,064 - INFO - Successfully saved courses to course_data.xlsx
