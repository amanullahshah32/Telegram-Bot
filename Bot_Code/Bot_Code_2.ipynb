# %%
import pandas as pd
import telebot
import threading
import time
import logging
import os

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Replace 'YOUR_BOT_TOKEN' with your actual bot token
bot_token = "7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o"

# Initialize the bot with the correct token
bot = telebot.TeleBot(bot_token)

# Dictionary to store user preferences
user_preferences = {}

# Load course data from Excel
def load_course_data():
    try:
        if os.path.exists('course_data.xlsx'):
            df = pd.read_excel('course_data.xlsx')
            logging.info('Course data loaded successfully from Excel')
            return df
        else:
            logging.warning('course_data.xlsx file does not exist')
            return pd.DataFrame()  # Return an empty DataFrame if file does not exist
    except Exception as e:
        logging.error(f'Error loading course data from Excel: {e}')
        return pd.DataFrame()  # Return an empty DataFrame in case of error

# Function to handle /start command
@bot.message_handler(commands=['start'])
def handle_start(message):
    bot.reply_to(message, "Welcome to the NSU Course Notifier Bot! Please use /setpref <course_name> <section> to set your preferred course and section. And then use /check to check the availability")

# Function to handle /setpref command
@bot.message_handler(commands=['setpref'])
def handle_setpref(message):
    if len(message.text.split()) != 3:
        bot.reply_to(message, "Usage: /setpref <course_name> <section>")
        return

    user_id = message.from_user.id
    course_name = message.text.split()[1].upper().strip()  # Normalize input
    section = message.text.split()[2].strip()  # Normalize input
    user_preferences[user_id] = (course_name, section)
    bot.reply_to(message, f"Preference set: {course_name} Section {section}")

# Function to handle /check command
@bot.message_handler(commands=['check'])
def handle_check(message):
    user_id = message.from_user.id
    if user_id not in user_preferences:
        bot.reply_to(message, "You have not set any preferences. Use /setpref to set your preference.")
        return

    course_name, section = user_preferences[user_id]
    course_data = load_course_data()

    # Strip any extra whitespace from course_name and section, and convert course_name to upper case
    course_name = course_name.strip().upper()
    section = section.strip()

    result = course_data[(course_data['Course Name'].str.strip().str.upper() == course_name) & 
                         (course_data['Section'].astype(str).str.strip() == section)]

    if not result.empty:
        seats_available = result.iloc[0]['Seats Available']
        bot.reply_to(message, f"Course: {course_name} Section: {section} Seats Available: {seats_available}")
        # Set up a one-time alert for this course and section if seats are zero
        if int(seats_available) == 0:
            set_seat_alert(user_id, course_name, section)
    else:
        bot.reply_to(message, f"No data found for Course: {course_name} Section: {section}")

# Store alerts for users who need seat notifications
seat_alerts = {}

def set_seat_alert(user_id, course_name, section):
    seat_alerts[user_id] = (course_name, section)
    logging.info(f'Seat alert set for user {user_id} for Course: {course_name} Section: {section}')

# Function to periodically check seat availability
def periodic_check():
    while True:
        try:
            course_data = load_course_data()
            for user_id, (course_name, section) in seat_alerts.items():
                course_name = course_name.strip().upper()  # Ensure consistency
                section = section.strip()
                result = course_data[(course_data['Course Name'].str.strip().str.upper() == course_name) & 
                                     (course_data['Section'].astype(str).str.strip() == section)]
                if not result.empty:
                    seats_available = result.iloc[0]['Seats Available']
                    if int(seats_available) > 0:
                        bot.send_message(user_id, f"Seats available for Course: {course_name} Section: {section} - {seats_available}")
                        del seat_alerts[user_id]  # Remove alert after notifying the user
        except Exception as e:
            logging.error(f'Error in periodic check: {e}')
        time.sleep(600)  # Check every 10 minutes

# Start the periodic check in a separate thread
threading.Thread(target=periodic_check, daemon=True).start()

# Run the bot
bot.polling()
# Out:
# 2024-07-03 13:57:07,737 - DEBUG - Starting new HTTPS connection (1): api.telegram.org:443
# 2024-07-03 13:57:08,521 - INFO - Course data loaded successfully from Excel
# 2024-07-03 13:57:10,992 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getMe HTTP/11" 200 230
# 2024-07-03 13:57:10,995 - DEBUG - Starting new HTTPS connection (1): api.telegram.org:443
# 2024-07-03 13:57:15,473 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=1&timeout=20 HTTP/11" 200 1054
# 2024-07-03 13:57:15,478 - DEBUG - Starting new HTTPS connection (1): api.telegram.org:443
# 2024-07-03 13:57:15,481 - DEBUG - Starting new HTTPS connection (1): api.telegram.org:443
# 2024-07-03 13:57:16,566 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=1878203122&text=Preference+set%3A+CSE445+Section+1&reply_parameters=%7B%22message_id%22%3A+560%7D HTTP/11" 200 602
# 2024-07-03 13:57:17,653 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=1878203122&text=Preference+set%3A+CSE445+Section+2&reply_parameters=%7B%22message_id%22%3A+561%7D HTTP/11" 200 602
# 2024-07-03 13:57:19,065 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=5699291765&text=Preference+set%3A+%3CCSE273%3E+Section+%3C2%3E&reply_parameters=%7B%22message_id%22%3A+559%7D HTTP/11" 200 613
# 2024-07-03 13:57:35,691 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215473&timeout=20 HTTP/11" 200 23
# 2024-07-03 13:57:37,269 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215473&timeout=20 HTTP/11" 200 353
# 2024-07-03 13:57:38,216 - INFO - Course data loaded successfully from Excel
# 2024-07-03 13:57:38,768 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=1878203122&text=Course%3A+CSE445+Section%3A+2+Seats+Available%3A+0&reply_parameters=%7B%22message_id%22%3A+565%7D HTTP/11" 200 603
# 2024-07-03 13:57:38,771 - INFO - Seat alert set for user 1878203122 for Course: CSE445 Section: 2
# 2024-07-03 13:57:47,976 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215474&timeout=20 HTTP/11" 200 357
# 2024-07-03 13:57:48,448 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=6011930786&text=Welcome+to+the+NSU+Course+Notifier+Bot%21+Please+use+%2Fsetpref+%3Ccourse_name%3E+%3Csection%3E+to+set+your+preferred+course+and+section.+And+then+use+%2Fcheck+to+check+the+availability&reply_parameters=%7B%22message_id%22%3A+567%7D HTTP/11" 200 842
# 2024-07-03 13:57:57,022 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215475&timeout=20 HTTP/11" 200 369
# 2024-07-03 13:57:57,496 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=6011930786&text=Preference+set%3A+HIS102+Section+12&reply_parameters=%7B%22message_id%22%3A+569%7D HTTP/11" 200 610
# 2024-07-03 13:57:59,633 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215476&timeout=20 HTTP/11" 200 357
# 2024-07-03 13:58:00,624 - INFO - Course data loaded successfully from Excel
# 2024-07-03 13:58:01,108 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=6011930786&text=Course%3A+HIS102+Section%3A+12+Seats+Available%3A+0&reply_parameters=%7B%22message_id%22%3A+571%7D HTTP/11" 200 610
# 2024-07-03 13:58:01,110 - INFO - Seat alert set for user 6011930786 for Course: HIS102 Section: 12
# 2024-07-03 13:58:02,043 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215477&timeout=20 HTTP/11" 200 355
# 2024-07-03 13:58:03,073 - INFO - Course data loaded successfully from Excel
# 2024-07-03 13:58:03,569 - DEBUG - https://api.telegram.org:443 "POST /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/sendMessage?chat_id=5699291765&text=No+data+found+for+Course%3A+%3CCSE273%3E+Section%3A+%3C2%3E&reply_parameters=%7B%22message_id%22%3A+573%7D HTTP/11" 200 609
# 2024-07-03 13:58:22,261 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 13:58:42,475 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 13:59:03,553 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 13:59:23,767 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 13:59:43,980 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:00:04,196 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:00:24,410 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:00:44,632 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:01:04,960 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:01:25,185 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:01:45,403 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:02:05,624 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:02:25,838 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:02:46,053 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:03:06,697 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:03:27,144 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:03:47,380 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:04:08,164 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:04:28,500 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:04:49,434 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:05:12,148 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:05:32,369 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:05:52,584 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:06:12,798 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:06:33,010 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:06:53,219 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:07:09,798 - INFO - Course data loaded successfully from Excel
# 2024-07-03 14:07:13,431 - DEBUG - https://api.telegram.org:443 "GET /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 HTTP/11" 200 23
# 2024-07-03 14:07:13,432 - DEBUG - Starting new HTTPS connection (1): api.telegram.org:443
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:615, in HTTPSConnection.connect(self)
#     614 sock: socket.socket | ssl.SSLSocket
# --> 615 self.sock = sock = self._new_conn()
#     616 server_hostname: str = self.host
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except SocketTimeout as e:
# --> 205     raise ConnectTimeoutError(
#     206         self,
#     207         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     208     ) from e
#     210 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x0000021F856F6F30>, 'Connection to api.telegram.org timed out. (connect timeout=20)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000021F856F6F30>, 'Connection to api.telegram.org timed out. (connect timeout=20)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[1], line 109
#     106 threading.Thread(target=periodic_check, daemon=True).start()
#     108 # Run the bot
# --> 109 bot.polling()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\__init__.py:1178, in TeleBot.polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, logger_level, allowed_updates, none_stop, restart_on_change, path_to_watch)
#    1175 logger.info('Starting your bot with username: [@%s]', self.user.username)
#    1177 if self.threaded:
# -> 1178     self.__threaded_polling(non_stop=non_stop, interval=interval, timeout=timeout, long_polling_timeout=long_polling_timeout,
#    1179                             logger_level=logger_level, allowed_updates=allowed_updates)
#    1180 else:
#    1181     self.__non_threaded_polling(non_stop=non_stop, interval=interval, timeout=timeout, long_polling_timeout=long_polling_timeout,
#    1182                                 logger_level=logger_level, allowed_updates=allowed_updates)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\__init__.py:1253, in TeleBot.__threaded_polling(self, non_stop, interval, timeout, long_polling_timeout, logger_level, allowed_updates)
#    1251     polling_thread.clear_exceptions()   #*
#    1252     self.worker_pool.clear_exceptions() #*
# -> 1253     raise e
#    1254 else:
#    1255     polling_thread.clear_exceptions()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\__init__.py:1214, in TeleBot.__threaded_polling(self, non_stop, interval, timeout, long_polling_timeout, logger_level, allowed_updates)
#    1212 polling_thread.put(self.__retrieve_updates, timeout, long_polling_timeout, allowed_updates=allowed_updates)
#    1213 or_event.wait()  # wait for polling thread finish, polling thread error or thread pool error
# -> 1214 polling_thread.raise_exceptions()
#    1215 self.worker_pool.raise_exceptions()
#    1216 error_interval = 0.25
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\util.py:111, in WorkerThread.raise_exceptions(self)
#     109 def raise_exceptions(self):
#     110     if self.exception_event.is_set():
# --> 111         raise self.exception_info
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\util.py:93, in WorkerThread.run(self)
#      90 logger.debug("Received task")
#      91 self.received_task_event.set()
# ---> 93 task(*args, **kwargs)
#      94 logger.debug("Task complete")
#      95 self.done_event.set()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\__init__.py:676, in TeleBot.__retrieve_updates(self, timeout, long_polling_timeout, allowed_updates)
#     674     logger.debug('Skipped all pending messages')
#     675     self.skip_pending = False
# --> 676 updates = self.get_updates(offset=(self.last_update_id + 1),
#     677                            allowed_updates=allowed_updates,
#     678                            timeout=timeout, long_polling_timeout=long_polling_timeout)
#     679 self.process_new_updates(updates)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\__init__.py:648, in TeleBot.get_updates(self, offset, limit, timeout, allowed_updates, long_polling_timeout)
#     618 def get_updates(self, offset: Optional[int]=None, limit: Optional[int]=None,
#     619         timeout: Optional[int]=20, allowed_updates: Optional[List[str]]=None,
#     620         long_polling_timeout: int=20) -> List[types.Update]:
#     621     """
#     622     Use this method to receive incoming updates using long polling (wiki). An Array of Update objects is returned.
#     623
#    (...)
#     646     :rtype: :obj:`list` of :class:`telebot.types.Update`
#     647     """
# --> 648     json_updates = apihelper.get_updates(
#     649         self.token, offset=offset, limit=limit, timeout=timeout, allowed_updates=allowed_updates,
#     650         long_polling_timeout=long_polling_timeout)
#     651     return [types.Update.de_json(ju) for ju in json_updates]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\apihelper.py:330, in get_updates(token, offset, limit, timeout, allowed_updates, long_polling_timeout)
#     328 if allowed_updates is not None:  # Empty lists should pass
#     329     payload['allowed_updates'] = json.dumps(allowed_updates)
# --> 330 return _make_request(token, method_url, params=payload)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telebot\apihelper.py:162, in _make_request(token, method_name, method, params, files)
#     158     result = http.request(
#     159         method, request_url, params=params, files=files,
#     160         timeout=(connect_timeout, read_timeout), proxies=proxy)
#     161 else:
# --> 162     result = _get_req_session().request(
#     163         method, request_url, params=params, files=files,
#     164         timeout=(connect_timeout, read_timeout), proxies=proxy)
#     166 logger.debug("The server returned: '{0}'".format(result.text.encode('utf8')))
#     168 json_result = _check_result(method_name, result)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='api.telegram.org', port=443): Max retries exceeded with url: /bot7498318810:AAFGObjMdONGYKg_WPc4JyWNiZjijULb68o/getUpdates?offset=352215478&timeout=20 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000021F856F6F30>, 'Connection to api.telegram.org timed out. (connect timeout=20)'))
